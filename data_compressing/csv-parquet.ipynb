# %%
import pandas as pd

# %% [markdown]
# # Read in csv file

# %%
df = pd.read_csv("/g/data/hh5/tmp/pa1490/Global_HWs/Analysis/Model/Ensemble_DataFrames/Decade/Ensemble1/HW_Parameter_Decade_Ensemble1_CMIP5_historical_tas.csv")
# Out:
# /jobfs/145565013.gadi-pbs/ipykernel_459212/1055282493.py:1: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/g/data/hh5/tmp/pa1490/Global_HWs/Analysis/Model/Ensemble_DataFrames/Decade/Ensemble1/HW_Parameter_Decade_Ensemble1_CMIP5_historical_tas.csv")

# %% [markdown]
# # Save to parquet file using zstd compression

# %%
df.to_parquet("/g/data/gb02/sg7549/philipp/test.parquet", compression="zstd")

# %% [markdown]
# # Read in parquet file with pandas

# %%
df = pd.read_parquet("/g/data/gb02/sg7549/philipp/test.parquet")

# %%
df
# Out:
#          Unnamed: 0               Region variable   CMIP         exp  \
# 0                 0          Russia_2010      tas  CMIP5  historical
# 1                 1          Russia_2010      tas  CMIP5  historical
# 2                 2          Russia_2010      tas  CMIP5  historical
# 3                 3          Russia_2010      tas  CMIP5  historical
# 4                 4          Russia_2010      tas  CMIP5  historical
# ...             ...                  ...      ...    ...         ...
# 4339153     4339153  East_Antarctic_2022      tas  CMIP5  historical
# 4339154     4339154  East_Antarctic_2022      tas  CMIP5  historical
# 4339155     4339155  East_Antarctic_2022      tas  CMIP5  historical
# 4339156     4339156  East_Antarctic_2022      tas  CMIP5  historical
# 4339157     4339157  East_Antarctic_2022      tas  CMIP5  historical
#
#         modeling_center         model model_run  start_date    end_date  ...  \
# ...
